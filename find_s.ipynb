# %%
import pandas as pd

# %%
data={
    "Eyes":["Round","Square","Square","Round","Square"],
    "Nose":["Triangle","Square","Triangle","Triangle","Square"],
    "Head":["Round","Square","Round","Round","Round"],
    "Color":["Purple","Green","Yellow","Green","Yellow"],
    "Hair":["Yes","Yes","Yes","No","Yes"],
    "Smile":["No","No","Yes","No","Yes"]
}

# %%
df=pd.DataFrame(data)

# %%
print(df)
# Out:
#      Eyes      Nose    Head   Color Hair Smile
# 0   Round  Triangle   Round  Purple  Yes    No
# 1  Square    Square  Square   Green  Yes    No
# 2  Square  Triangle   Round  Yellow  Yes   Yes
# 3   Round  Triangle   Round   Green   No    No
# 4  Square    Square   Round  Yellow  Yes   Yes

# %%
df.to_csv("finds_data.csv",index=False)
print("Dataset saved")
# Out:
# Dataset saved

# %%
import pandas as pd
def find_s_algorithm(data):
    specific_hypothesis=data.iloc[0,:-1].values
    print(specific_hypothesis)
    for i, row in data.iterrows():
        if row[-1]=='Yes':
            for j in range(len(specific_hypothesis)):
                if row[j]!=specific_hypothesis[j]:
                    specific_hypothesis[j]='?'
    return specific_hypothesis

# %%
df=pd.read_csv('finds_data.csv')
print("Final Hypothesis:",find_s_algorithm(df))
# Out:
# ['Round' 'Triangle' 'Round' 'Purple' 'Yes']
# Final Hypothesis: ['?' '?' 'Round' '?' 'Yes']
# /var/folders/90/9lp7p4rn5ql5r810jwcgqvxh0000gn/T/ipykernel_47839/1248157391.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[-1]=='Yes':
# /var/folders/90/9lp7p4rn5ql5r810jwcgqvxh0000gn/T/ipykernel_47839/1248157391.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[j]!=specific_hypothesis[j]:
